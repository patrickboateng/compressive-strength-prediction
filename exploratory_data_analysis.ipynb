# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Concrete_Data.csv')

# %%
df.columns = ['cement', 'BFS', 'FA', 'water', 'SPZ', 'coarse', 'fine', 'age', 'strength']

# %%
df['W/C'] = df['water'] / df['cement']
df['A/C'] = (df['fine'] + df['coarse']) / df['cement']
df['F/C'] = df['fine'] / df['cement']
df['C/C'] = df['coarse'] / df['cement']
df.round(decimals=2)
# Out:
#       cement    BFS     FA  water   SPZ  coarse   fine  age  strength   W/C  \
# 0      540.0    0.0    0.0  162.0   2.5  1040.0  676.0   28     79.99  0.30
# 1      540.0    0.0    0.0  162.0   2.5  1055.0  676.0   28     61.89  0.30
# 2      332.5  142.5    0.0  228.0   0.0   932.0  594.0  270     40.27  0.69
# 3      332.5  142.5    0.0  228.0   0.0   932.0  594.0  365     41.05  0.69
# 4      198.6  132.4    0.0  192.0   0.0   978.4  825.5  360     44.30  0.97
# ...      ...    ...    ...    ...   ...     ...    ...  ...       ...   ...
# 1025   276.4  116.0   90.3  179.6   8.9   870.1  768.3   28     44.28  0.65
# 1026   322.2    0.0  115.6  196.0  10.4   817.9  813.4   28     31.18  0.61
# 1027   148.5  139.4  108.6  192.7   6.1   892.4  780.0   28     23.70  1.30
# 1028   159.1  186.7    0.0  175.6  11.3   989.6  788.9   28     32.77  1.10
# 1029   260.9  100.5   78.3  200.6   8.6   864.5  761.5   28     32.40  0.77
#
#         A/C   F/C   C/C
# 0      3.18  1.25  1.93
# ...

# %%
df['W/C'] = df['water'] / df['cement']
df['C/A'] = df['cement'] / (df['fine'] + df['coarse']) 
df['C/F'] = df['cement'] / df['fine']
df['C/C'] = df['cement'] / df['coarse']
df.round(decimals=2)

print(max(df['W/C']))
print(max(df['C/A']))
print(max(df['C/F']))
print(max(df['C/C']))
df
# Out:
# 1.8823529411764706
# 0.3228139381985536
# 0.8809135399673735
# 0.6441947565543071
#       cement    BFS     FA  water   SPZ  coarse   fine  age  strength  \
# 0      540.0    0.0    0.0  162.0   2.5  1040.0  676.0   28     79.99
# 1      540.0    0.0    0.0  162.0   2.5  1055.0  676.0   28     61.89
# 2      332.5  142.5    0.0  228.0   0.0   932.0  594.0  270     40.27
# 3      332.5  142.5    0.0  228.0   0.0   932.0  594.0  365     41.05
# 4      198.6  132.4    0.0  192.0   0.0   978.4  825.5  360     44.30
# ...      ...    ...    ...    ...   ...     ...    ...  ...       ...
# 1025   276.4  116.0   90.3  179.6   8.9   870.1  768.3   28     44.28
# 1026   322.2    0.0  115.6  196.0  10.4   817.9  813.4   28     31.18
# 1027   148.5  139.4  108.6  192.7   6.1   892.4  780.0   28     23.70
# 1028   159.1  186.7    0.0  175.6  11.3   989.6  788.9   28     32.77
# 1029   260.9  100.5   78.3  200.6   8.6   864.5  761.5   28     32.40
#
#            W/C       C/A       C/F       C/C
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data=df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
def plot(col1: str, filename):
    
    x = df[col1]
    y = df['strength']
    
    sns.set_style('whitegrid')
    sns.regplot(x=x, y=y)
    
#     plt.savefig(f'C:\\Users\\boate\\OneDrive\\Desktop\\JOURNAL-PAPER\\LATEX\\Elsevier Article (elsarticle) Template\\{filename}.jpg', bbox_inches='tight', dpi=100)

# %%
plot(col1='W/C', filename='water_cement')

# %%
plot(col1='C/A', filename='agg_cement')

# %%
plot(col1='C/F', filename='fine_cement')

# %%
plot(col1='C/C', filename='coarse_cement')
